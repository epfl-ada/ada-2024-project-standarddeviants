# %%
import os


print(
    "".join(
        [
            f"""
        <div class="col">
          <div class="card shadow-sm">
            <img src="frontend/figures/data_story/{file_path}" class="img-fluid" alt="...">
            <div class="card-body">
              <!-- <p class="card-text">This is a wider card with supporting text below as a natural lead-in to additional content. This content is a little bit longer.</p> -->
              <div class="d-flex justify-content-between align-items-center">
                <div class="btn-group">
                  <a class="btn btn-sm btn-outline-primary" href="index.html#{file_path.replace(".svg", "")}">View in Data Story</a>
                  <a class="btn btn-sm btn-outline-secondary" href="frontend/figures/data_story/{file_path.replace(".svg", ".html")}">View in fullscreen</a>
                </div>
                <!-- <small class="text-body-secondary">9 mins</small> -->
              </div>
            </div>
          </div>
        </div>
        """
            for file_path in filter(
                lambda file: file.endswith("svg"), os.listdir("figures/data_story")
            )
        ]
    )
)
# Out:
#         <div class="col">
#           <div class="card shadow-sm">
#             <img src="frontend/figures/data_story/HIndex_Target.svg" class="img-fluid" alt="...">
#             <div class="card-body">
#               <!-- <p class="card-text">This is a wider card with supporting text below as a natural lead-in to additional content. This content is a little bit longer.</p> -->
#               <div class="d-flex justify-content-between align-items-center">
#                 <div class="btn-group">
#                   <a class="btn btn-sm btn-outline-primary" href="index.html#HIndex_Target">View in Data Story</a>
#                   <a class="btn btn-sm btn-outline-secondary" href="frontend/figures/data_story/HIndex_Target.html">View in fullscreen</a>
#                 </div>
#                 <!-- <small class="text-body-secondary">9 mins</small> -->
#               </div>
#             </div>
#           </div>
#         </div>
#
#         <div class="col">
# ...

# %%
print(
    "".join(
        [
            f"""
        <div class="col">
          <div class="card shadow-sm">
            <img src="frontend/figures/availability/{file_path}" class="img-fluid" alt="...">
            <div class="card-body">
              <!-- <p class="card-text">This is a wider card with supporting text below as a natural lead-in to additional content. This content is a little bit longer.</p> -->
              <div class="d-flex justify-content-between align-items-center">
                <div class="btn-group">
                  <a class="btn btn-sm btn-outline-primary" href="data.html#{file_path.replace(".svg", "")}">View in Data Page</a>
                  <a class="btn btn-sm btn-outline-secondary" href="frontend/figures/availability/{file_path.replace(".svg", ".html")}">View in fullscreen</a>
                </div>
                <!-- <small class="text-body-secondary">9 mins</small> -->
              </div>
            </div>
          </div>
        </div>
        """
            for file_path in filter(
                lambda file: file.endswith("svg"), os.listdir("figures/availability")
            )
        ]
    )
)
# Out:
#         <div class="col">
#           <div class="card shadow-sm">
#             <img src="frontend/figures/availability/availability_bk.svg" class="img-fluid" alt="...">
#             <div class="card-body">
#               <!-- <p class="card-text">This is a wider card with supporting text below as a natural lead-in to additional content. This content is a little bit longer.</p> -->
#               <div class="d-flex justify-content-between align-items-center">
#                 <div class="btn-group">
#                   <a class="btn btn-sm btn-outline-primary" href="data.html#availability_bk">View in Data Page</a>
#                   <a class="btn btn-sm btn-outline-secondary" href="frontend/figures/availability/availability_bk.html">View in fullscreen</a>
#                 </div>
#                 <!-- <small class="text-body-secondary">9 mins</small> -->
#               </div>
#             </div>
#           </div>
#         </div>
#
#         <div class="col">
# ...

# %%
print(
    "".join(
        [
            f"""
        <div class="col">
          <div class="card shadow-sm">
            <img src="frontend/figures/other/{file_path}" class="img-fluid" alt="...">
            <div class="card-body">
              <!-- <p class="card-text">This is a wider card with supporting text below as a natural lead-in to additional content. This content is a little bit longer.</p> -->
              <div class="d-flex justify-content-between align-items-center">
                <div class="btn-group">
                  <a class="btn btn-sm btn-outline-primary" href="https://github.com/epfl-ada/ada-2024-project-standarddeviants/blob/main/results.ipynb">View explanation on Github</a>
                  <a class="btn btn-sm btn-outline-secondary" href="frontend/figures/other/{file_path.replace(".svg", ".html")}">View in fullscreen</a>
                </div>
                <!-- <small class="text-body-secondary">9 mins</small> -->
              </div>
            </div>
          </div>
        </div>
        """
            for file_path in filter(
                lambda file: file.endswith("svg"), os.listdir("figures/other")
            )
        ]
    )
)
# Out:
#         <div class="col">
#           <div class="card shadow-sm">
#             <img src="frontend/figures/other/Patent_Status_Diseases.svg" class="img-fluid" alt="...">
#             <div class="card-body">
#               <!-- <p class="card-text">This is a wider card with supporting text below as a natural lead-in to additional content. This content is a little bit longer.</p> -->
#               <div class="d-flex justify-content-between align-items-center">
#                 <div class="btn-group">
#                   <a class="btn btn-sm btn-outline-primary" href="https://github.com/epfl-ada/ada-2024-project-standarddeviants/blob/main/results.ipynb">View explanation on Github</a>
#                   <a class="btn btn-sm btn-outline-secondary" href="frontend/figures/other/Patent_Status_Diseases.html">View in fullscreen</a>
#                 </div>
#                 <!-- <small class="text-body-secondary">9 mins</small> -->
#               </div>
#             </div>
# ...
